# %%
# read the file: /home/wyt/Dyn/Dynamical-masses/results/multi_metallicity/broken_powerlaw_samples_fehbin0_feh-0.20.txt
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('/home/wyt/Dyn/Dynamical-masses/results/multi_metallicity/broken_powerlaw_samples_fehbin0_feh-0.20.txt')

# %%
np.shape(data)
# Out:
# (3000, 4)

# %%
data[1]
# Out:
# array([  2.01432037, -14.90788651,   1.21633267, -16.91318321])
